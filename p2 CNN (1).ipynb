# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(
    rescale=1./255,
)


test_datagen = ImageDataGenerator(rescale=1./255)


traindata_augmented = train_datagen.flow_from_directory(
    '/content/drive/MyDrive/broadway py w ai/Brain Tumor MRI Dataset/Training',
    target_size = (100, 100),
    class_mode = 'categorical',
    batch_size = 32
)


testdata_no_aug = test_datagen.flow_from_directory(
    '/content/drive/MyDrive/broadway py w ai/Brain Tumor MRI Dataset/Testing',
    target_size = (100, 100),
    class_mode = 'categorical',
    batch_size = 32
)
# Out:
# Found 1617 images belonging to 4 classes.
# Found 600 images belonging to 4 classes.

# %%
model = Sequential([
    Input((100, 100, 3)),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dropout(0.2),
    Dense(4, activation='softmax')
])

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics=['accuracy'] )

# %%
fitted = model.fit(traindata_augmented, epochs=15)
# Out:
# Epoch 1/15
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.6962 - loss: 0.6512
# Epoch 2/15
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 146ms/step - accuracy: 0.8617 - loss: 0.2978
# Epoch 3/15
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9264 - loss: 0.2099
# Epoch 4/15
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.9612 - loss: 0.1020
# Epoch 5/15
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9777 - loss: 0.0746
# Epoch 6/15
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - accuracy: 0.9779 - loss: 0.0619
# Epoch 7/15
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9920 - loss: 0.0349
# Epoch 8/15
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - accuracy: 0.9916 - loss: 0.0235
# Epoch 9/15
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 121ms/step - accuracy: 0.9984 - loss: 0.0170
# Epoch 10/15
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.9988 - loss: 0.0095
# Epoch 11/15
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9929 - loss: 0.0188
# Epoch 12/15
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.9928 - loss: 0.0168
# Epoch 13/15
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9925 - loss: 0.0298
# Epoch 14/15
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - accuracy: 0.9964 - loss: 0.0131
# Epoch 15/15
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - accuracy: 0.9909 - loss: 0.0233

# %%
loss, accuracy = model.evaluate(testdata_no_aug)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 165s 9s/step - accuracy: 0.9715 - loss: 0.2359

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
img_path = input('Enter Image Path')
img_data = image.load_img(img_path, target_size=(100, 100))
img_array = image.img_to_array(img_data)
img_array = img_array / 255.0
img_array = np.expand_dims(img_array, axis=0)
prediction = model.predict(img_array)
# Out:
# Enter Image Path/content/drive/MyDrive/broadway py w ai/pituitary tumor.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step

# %%
classes = traindata_augmented.class_indices

# %%
data = list(classes.keys())

# %%
data
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
data[np.argmax(prediction)]
# Out:
# 'pituitary'
